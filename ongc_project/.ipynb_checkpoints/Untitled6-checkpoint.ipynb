# %%
import petropy as pt
import lasio
file_path=r'C:\Users\Administrator\Desktop\B_Wells\B_1.las'
log = pt.Log(file_path)
top=min(las.depth_m)
print(top)
height=max(las.depth_m)
print(height)
viewer=pt.LogViewer(log,top=top,height=height,template_xml_path=r"C:\Users\Administrator\Desktop\pyproject\template.xml")
s=r'C:\Users\Administrator\Desktop\pyproject\log.png'
viewer.fig.savefig(s)
# Out:
# Header section Parameter regexp=~P was not found.
# C:\Users\Public\Anaconda3\lib\site-packages\petropy\graphs.py:590: RuntimeWarning: invalid value encountered in greater_equal
#   where = x >= ci,
# 181.204
# 1243.432
# C:\Users\Public\Anaconda3\lib\site-packages\petropy\graphs.py:611: RuntimeWarning: invalid value encountered in greater
#   where = v < x)
# C:\Users\Public\Anaconda3\lib\site-packages\petropy\graphs.py:612: RuntimeWarning: invalid value encountered in greater
#   ax.plot(v * np.ones(len(self.log[0][v < x])),
# C:\Users\Public\Anaconda3\lib\site-packages\petropy\graphs.py:613: RuntimeWarning: invalid value encountered in greater
#   self.log[0][v < x], c = "#000000",
# C:\Users\Public\Anaconda3\lib\site-packages\petropy\graphs.py:634: RuntimeWarning: invalid value encountered in less
#   where = x < v)
# C:\Users\Public\Anaconda3\lib\site-packages\petropy\graphs.py:636: RuntimeWarning: invalid value encountered in less
# ...

# %%
import tkinter as tk
root=tk.Tk()
image=tk.PhotoImage(file=r'C:\Users\Administrator\Desktop\pyproject\log.png')
label=tk.Label(image=image)
label.pack()
root.mainloop()

# %%
import lasio
las=lasio.read(file_path)
# Out:
# Header section Parameter regexp=~P was not found.
